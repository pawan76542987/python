# %% [markdown]
# <a href="https://colab.research.google.com/github/pawan76542987/python/blob/main/Pandas_class8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dct = {
    'name': ['Tom', 'Nick', 'Krish', 'Jack'],
    'age': [20, 21, 19, 18],
    'roll': [1, 2, 3, 4]
}

df = pd.DataFrame(dct, index = ['a', 'b', 'c', 'd'])

display(df)
# Out:
#     name  age  roll
# a    Tom   20     1
# b   Nick   21     2
# c  Krish   19     3
# d   Jack   18     4

# %%
df = pd.read_csv('student_data.csv')

# df[df["assignments_completed"] > 3]


# # Rename columns
df.rename(columns = {'assignments_completed': 'assign_completed'}, inplace = True)


df








# # Rename columns
# df.rename()

# # Remove rows or columns
# df.drop()
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
df['attendence'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'attendence'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3554/4183838090.py in <cell line: 0>()
# ----> 1 df['attendence'].unique()
#
# ...

# %%
# Import pandas library
import pandas as pd

# Create a Series
a = pd.Series()

# Create a DataFrame
pd.DataFrame()

# Read data from a CSV file
pd.read_csv()

# Read data from an Excel file
pd.read_excel()

# Read data from a JSON file
pd.read_json()

# Display the first 5 rows
df.head()

# Display the last 5 rows
df.tail()

# Show DataFrame information (columns, types, null values)
df.info()

# Generate statistical summary
# first tell them about quartiles (q1, q2, q3) and interquartile range (IQR)
df.describe()

# Return DataFrame dimensions (rows, columns)
df.shape

# Display column names
df.columns

# Display row index labels
df.index

# Select a column
df["column_name"]

# Select rows/columns by label
df.loc[]

# Select rows/columns by integer position
df.iloc[]

# Filter rows based on a condition
df[df["Age"] > 25]

# Add or update a column
df["new_column"] = values

# Rename columns
df.rename()

# Remove rows or columns
df.drop()

# Remove missing values
df.dropna()

# Sort values by column
df.sort_values()

# sort index
df.sort_index()

# Check for missing values
df.isnull()

# Check for non-missing values
df.notnull()

# Count missing values
df.isnull().sum()

# Replace missing values
df.fillna()

# Find unique values
df.unique() # For a Series only

# Count unique values
df.nunique()

# Aggregate multiple statistics
df.agg()

# Group data and aggregate
df.groupby()

# Apply a function to values
df.apply()

# Merge DataFrames (SQL-style join)
pd.merge()    ### Highly recommended to learn the parameters of merge function (like on, how, left_on, right_on, etc.)

# Concatenate DataFrames
pd.concat()

# Create a pivot table
df.pivot_table()
# df.pivot_table(values=None, index=None, columns=None, aggfunc='mean')

# Remove duplicate rows
df.drop_duplicates()

# Convert column to datetime
pd.to_datetime()

# Extract year from datetime
df["date"].dt.year

# Extract month from datetime
df["date"].dt.month

# Extract day from datetime
df["date"].dt.day

# Calculate sum
df.sum()

# Calculate mean
df.mean()

# Calculate median
df.median()

# Find minimum value
df.min()

# Find maximum value
df.max()

# Count non-null values
df.count()

# Calculate standard deviation
df.std()

# Calculate variance
df.var()

# Calculate correlation
df.corr()

# Convert DataFrame to dictionary
df.to_dict()

# Save DataFrame to CSV
df.to_csv()

# Save DataFrame to Excel
df.to_excel()

# Save DataFrame to JSON
df.to_json()

# %%
import pandas as pd

df = pd.read_csv('student_data.csv')

# %%
df.groupby('placement_status')['placement_status'].agg('count')
# Out:
# placement_status
# Not Placed    1641
# Placed        8351
# Name: placement_status, dtype: int64

# %%
df.groupby('placement_status')['study_hours'].mean()
# Out:
# placement_status
# Not Placed    3.125533
# Placed        6.552748
# Name: study_hours, dtype: float64

# %%
def grades(score):
    if score >= 90:
        return 'A'
    elif score >= 80:
        return 'B'
    elif score >= 70:
        return 'C'
    elif score >= 60:
        return 'D'
    else:
        return 'F'

df['grade'] = df['exam_score'].apply(grades)
df
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56          8.0               7
# 1               4          69          5.0               3
# 2              11          60          7.0               6
# 3               8          99          9.0               8
# 4               5          52          8.0               6
# ...           ...         ...          ...             ...
# 9995            2          58          9.0               7
# 9996            7          98          6.0               9
# 9997           10          44          8.0               5
# 9998           10          75          7.0               5
# 9999            2          70          6.0              11
#
#       assignments_completed  previous_score  exam_score placement_status  \
# 0                        10              62      100.00           Placed
# 1                         8              56         NaN           Placed
# ...
